# %%
import pandas as pd
df = pd.read_csv('fifa_eda.csv')

# %% [markdown]
# # Analysing Features

# %%
df.head(10)
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
# 5  183277          E. Hazard   27     Belgium       91         91
# 6  177003          L. Modrić   32     Croatia       91         91
# 7  176580          L. Suárez   31     Uruguay       91         91
# 8  155862       Sergio Ramos   32       Spain       91         91
# 9  200389           J. Oblak   25    Slovenia       90         93
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
# ...

# %%
df.describe(include= 'number')
# Out:
#                   ID           Age       Overall     Potential          Value  \
# count   18207.000000  18207.000000  18207.000000  18207.000000   17955.000000
# mean   214298.338606     25.122206     66.238699     71.307299    2444.530214
# std     29965.244204      4.669943      6.908930      6.136496    5626.715434
# min        16.000000     16.000000     46.000000     48.000000      10.000000
# 25%    200315.500000     21.000000     62.000000     67.000000     325.000000
# 50%    221759.000000     25.000000     66.000000     71.000000     700.000000
# 75%    236529.500000     28.000000     71.000000     75.000000    2100.000000
# max    246620.000000     45.000000     94.000000     95.000000  118500.000000
#
#                Wage  International Reputation   Skill Moves        Joined  \
# count  18207.000000              18159.000000  18159.000000  18207.000000
# mean       9.731312                  1.113222      2.361308   2016.420607
# ...

# %%
df.describe(include= 'object')
# Out:
#                 Name Nationality          Club Preferred Foot Position  \
# count          18207       18207         17966          18207    18207
# unique         17194         164           651              2       27
# top     J. Rodríguez     England  FC Barcelona          Right       ST
# freq              11        1662            33          13996     2154
#
#        Contract Valid Until
# count                 17918
# unique                   35
# top              2019-01-01
# freq                   4870

# %%
df[df['Potential']==95.000000]
# Out:
#         ID       Name  Age Nationality  Overall  Potential  \
# 25  231747  K. Mbappé   19      France       88         95
#
#                    Club    Value   Wage Preferred Foot  \
# 25  Paris Saint-Germain  81000.0  100.0          Right
#
#     International Reputation  Skill Moves Position  Joined  \
# 25                       3.0          5.0       RM    2018
#
#    Contract Valid Until    Height  Weight  Release Clause
# 25           2022-01-01  5.833333   161.0        166100.0

# %% [markdown]
# # Missing Values

# %%
df.isnull().sum()
# Out:
# ID                            0
# Name                          0
# Age                           0
# Nationality                   0
# Overall                       0
# Potential                     0
# Club                        241
# Value                       252
# Wage                          0
# Preferred Foot                0
# International Reputation     48
# Skill Moves                  48
# Position                      0
# Joined                        0
# Contract Valid Until        289
# Height                        0
# Weight                        0
# Release Clause                0
# dtype: int64

# %%
df[]

# %% [markdown]
# # Indian players

# %%
df['Nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy', 'Egypt', 'Colombia', 'Denmark', 'Gabon', 'Wales',
#        'Senegal', 'Costa Rica', 'Slovakia', 'Netherlands',
#        'Bosnia Herzegovina', 'Morocco', 'Serbia', 'Algeria', 'Austria',
#        'Greece', 'Chile', 'Sweden', 'Korea Republic', 'Finland', 'Guinea',
#        'Montenegro', 'Armenia', 'Switzerland', 'Norway', 'Czech Republic',
#        'Scotland', 'Ghana', 'Central African Rep.', 'DR Congo',
#        'Ivory Coast', 'Russia', 'Ukraine', 'Iceland', 'Mexico', 'Jamaica',
#        'Albania', 'Venezuela', 'Japan', 'Turkey', 'Ecuador', 'Paraguay',
#        'Mali', 'Nigeria', 'Cameroon', 'Dominican Republic', 'Israel',
#        'Kenya', 'Hungary', 'Republic of Ireland', 'Romania',
#        'United States', 'Cape Verde', 'Australia', 'Peru', 'Togo',
# ...

# %%
Ind = df[df['Nationality']=='India']

# %%
Ind
# Out:
#            ID             Name  Age Nationality  Overall  Potential Club  \
# 8605   190939       S. Chhetri   33       India       67         67  NaN
# 10011  223763       S. Jhingan   24       India       65         71  NaN
# 12598  217225    J. Lalpekhlua   27       India       63         64  NaN
# 12811  225213  G. Singh Sandhu   26       India       63         68  NaN
# 13508  238205    A. Edathodika   31       India       62         62  NaN
# 14054  231461        P. Halder   25       India       61         67  NaN
# 14199  228188         P. Kotal   24       India       61         66  NaN
# 14218  208485         L. Ralte   25       India       61         62  NaN
# 14705  223764           N. Das   24       India       60         65  NaN
# 14786  233524         U. Singh   22       India       60         67  NaN
# 14915  228199       H. Narzary   24       India       60         66  NaN
# 15356  212502         R. Singh   28       India       59         59  NaN
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Distribution of preffered food

# %%
import matplotlib.pyplot as plt
import seaborn as sns
label = Ind['Preferred Foot'].value_counts().index
count = Ind['Preferred Foot'].value_counts()/len (Ind)*100
plt.pie(count,labels=label,autopct='%1.2f%%');

# %%
import seaborn as sns
sns.countplot(data = Ind ,x='Preferred Foot')
# Out:
# <Axes: xlabel='Preferred Foot', ylabel='count'>

# %%
sns.countplot()

# %%
count.plot(kind='bar',)
# Out:
# <Axes: xlabel='Preferred Foot'>

# %% [markdown]
# # Age distribution of players

# %%
Ind['Age']
# Out:
# 8605     33
# 10011    24
# 12598    27
# 12811    26
# 13508    31
# 14054    25
# 14199    24
# 14218    25
# 14705    24
# 14786    22
# 14915    24
# 15356    28
# 15643    22
# 15652    20
# 15855    25
# 15864    25
# 15884    31
# 16135    22
# 16265    26
# 16450    31
# 16499    28
# 16539    23
# 16793    31
# 16903    19
# 16976    21
# 17129    26
# 17197    21
# 17339    23
# 17436    20
# 17539    21
# Name: Age, dtype: int64

# %%
sns.histplot(x='Age',data=Ind,kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# # International Reputation

# %%
Ind['International Reputation']
# Out:
# 8605     1.0
# 10011    1.0
# 12598    1.0
# 12811    1.0
# 13508    1.0
# 14054    1.0
# 14199    1.0
# 14218    1.0
# 14705    1.0
# 14786    1.0
# 14915    1.0
# 15356    1.0
# 15643    1.0
# 15652    1.0
# 15855    1.0
# 15864    1.0
# 15884    1.0
# 16135    1.0
# 16265    1.0
# 16450    1.0
# 16499    1.0
# 16539    1.0
# 16793    1.0
# 16903    1.0
# 16976    1.0
# 17129    1.0
# 17197    1.0
# 17339    1.0
# 17436    1.0
# 17539    1.0
# Name: International Reputation, dtype: float64

# %%
sns.countplot(x='International Reputation',data=Ind)
# Out:
# <Axes: xlabel='International Reputation', ylabel='count'>

# %% [markdown]
# # Potential Score of player

# %%
Ind['Potential']
# Out:
# 8605     67
# 10011    71
# 12598    64
# 12811    68
# 13508    62
# 14054    67
# 14199    66
# 14218    62
# 14705    65
# 14786    67
# 14915    66
# 15356    59
# 15643    65
# 15652    71
# 15855    61
# 15864    62
# 15884    58
# 16135    66
# 16265    60
# 16450    57
# 16499    57
# 16539    63
# 16793    56
# 16903    64
# 16976    70
# 17129    58
# 17197    64
# 17339    63
# 17436    67
# 17539    62
# Name: Potential, dtype: int64

# %%
sns.histplot(x='Potential',data=Ind,kde=True)
# Out:
# <Axes: xlabel='Potential', ylabel='Count'>

# %% [markdown]
# # Box plot for top 10 Nationalities

# %%
df['Nationality'].value_counts().head(5)
# Out:
# Nationality
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Name: count, dtype: int64

# %%
df1=df[df['Nationality'].isin(['England', 'Spain','Germany','Spain','Argentina','France'])]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x='Nationality',y='Age',data=df1)
plt.grid(True)

# %%
df.groupby('Nationality')['Age'].describe().head()
# Out:
#              count       mean       std   min    25%   50%    75%   max
# Nationality
# Afghanistan    4.0  22.500000  2.645751  20.0  20.75  22.0  23.75  26.0
# Albania       40.0  24.025000  3.905863  18.0  21.00  24.0  27.00  34.0
# Algeria       60.0  27.050000  3.748107  19.0  25.00  27.0  29.25  35.0
# Andorra        1.0  28.000000       NaN  28.0  28.00  28.0  28.00  28.0
# Angola        15.0  25.866667  3.997618  19.0  23.50  25.0  28.50  34.0

# %%
df.sort_values(by='Age',ascending=True).head(10)
# Out:
#            ID            Name  Age          Nationality  Overall  Potential  \
# 18206  246269       G. Nugent   16              England       46         66
# 17743  244752       J. Olstad   16               Norway       52         69
# 13293  246594     H. Massengo   16               France       62         75
# 16081  241552     J. Italiano   16            Australia       58         79
# 18166  243621        N. Ayéva   16               Sweden       48         72
# 17712  245470        K. Broda   16               Poland       53         74
# 17354  242240     L. D'Arrigo   16            Australia       54         71
# 13567  246419  Y. Verschaeren   16              Belgium       62         83
# 16927  243646       B. Nygren   16               Sweden       56         73
# 18018  243722     B. O'Gorman   16  Republic of Ireland       50         69
#
#                   Club  Value  Wage Preferred Foot  International Reputation  \
# ...
